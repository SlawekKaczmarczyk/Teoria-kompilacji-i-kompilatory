# %% [markdown]
# **Console can be cluttered with print statements, no error means it's fine**

# %%
import lexer_parser as lexer_parser
lexer = lexer_parser.lexer
parser = lexer_parser.parser
from state import State
from lang_types import *

def run_code(code,state=None):
    result = parser.parse(lexer.input(code))
    if state != None:
        result.grant_state(state)
    result.evaluate()
    
    return result.state


# code = """
#     (1+1)*2/3+(1);
#     """
# state = run_code(code)

code = """
    var x <- 1;
    """
state = run_code(code)

code = """
    var x <- "qweasdzxc";
    """
state = run_code(code)

code = """
    var x <- true;
    """
state = run_code(code)

code = """
    var x <- "a";
    var y <- false;
    var z <- null;
    var w <- 345;
    """
state = run_code(code)
assert state.namespaces['root']['x'].value == "a"
assert type(state.namespaces['root']['x']) == String
assert state.namespaces['root']['y'].value == False
assert type(state.namespaces['root']['y']) == Bool
assert state.namespaces['root']['z'].value == None
assert type(state.namespaces['root']['z']) == Null
assert state.namespaces['root']['w'].value == 345
assert type(state.namespaces['root']['w']) == Number

code = """
    if true {
        print 2;
    };
    """
state = run_code(code)

code = """
    var x <- 1;
    if true {
        var x <- 0;
        print "this value should be 0: "+ (x).STR();
    };
    print x;
    """
state = run_code(code)

code = """
    if false {
        print "this shouldn't appear (if false)";
    };
    """
state = run_code(code)

code = """
    if true {
        print "this should appear (if true)";
    };
    """
state = run_code(code)


code = """
        var x <- 5;
        print "this value should be 5: " + x.STR();
    """
state = run_code(code)

code = """
        1.PLUS(2);
        1.MINUS(2);
        1.DIVIDE(2);
        1.TIMES(2);
        ("ASD").PLUS("ZXC");
    """
state = run_code(code)


code = """
        print 1;
    """
state = run_code(code)

code = """
        print 1;
    """
state = run_code(code)

code = """
   print 1 = 1;
   var x <- "asd";
   var y <- "asd";
   print x=y;
   
   """
state = run_code(code)

code = """
   var i <- 5;
   var x <= i;
   
   print "should be 5: " + x.REF().STR();
   
   """
state = run_code(code)

code = """
   var i <- 5;
   var x <= i;
   
   x.SET(0);
   
   print "should be 0: " + i.STR();
   
   
   """
state = run_code(code)

code = """
   var i <- 5;
   var x <= i;
   i <- 2;
   
   
   print "should be 2: " + x.REF().STR();
   
   """
state = run_code(code)

code = """
   var i <- 5;
   
   until i = 0 {
   print "odliczanie 5 do 0 :" + i.STR();
   i <- i-1;
   };
   
   
   """
state = run_code(code)


#tu źle działa, priorytet operatora unarnego MINUS trzeba ogarnąć
code = """
  print "should be true: " +(0 = 2 -3+1).STR();
   
   
   """
state = run_code(code)

code = """
  var x <- 0 << 0;
  print "this should be false: " + x.STR();
   
   """
state = run_code(code)

code = """
  var x <- 0 << 4;
  print "this should be true: " + x.STR();
   
   """
state = run_code(code)

code = """
  var x <- 2 >> 8;
  print "this should be false: " + x.STR();
   
   """
state = run_code(code)

code = """
  var x <- 80 >> 8;
  print "this should be true: " + x.STR();
   
   """
state = run_code(code)

code = """
  var x <- 2;
  var y <- 1+1;
  
  print x = y;
   
   """
state = run_code(code)
# Out:
# 2
# this value should be 0: 0
# 1
# this should appear (if true)
# this value should be 5: 5
# 1
# 1
# true
# true
# should be 5: 5
# should be 0: 0
# should be 2: 2
# cond result False
# is cond true False
# odliczanie 5 do 0 :5
# cond result False
# is cond true False
# odliczanie 5 do 0 :4
# cond result False
# is cond true False
# odliczanie 5 do 0 :3
# cond result False
# is cond true False
# odliczanie 5 do 0 :2
# cond result False
# is cond true False
# odliczanie 5 do 0 :1
# cond result False
# is cond true False
# odliczanie 5 do 0 :0
# cond result False
# is cond true False
# odliczanie 5 do 0 :-1
# cond result False
# is cond true False
# odliczanie 5 do 0 :-2
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3
# cond result False
# is cond true False
# odliczanie 5 do 0 :-4
# cond result False
# is cond true False
# odliczanie 5 do 0 :-5
# cond result False
# is cond true False
# odliczanie 5 do 0 :-6
# cond result False
# is cond true False
# odliczanie 5 do 0 :-7
# cond result False
# is cond true False
# odliczanie 5 do 0 :-8
# cond result False
# is cond true False
# odliczanie 5 do 0 :-9
# cond result False
# is cond true False
# odliczanie 5 do 0 :-10
# cond result False
# is cond true False
# odliczanie 5 do 0 :-11
# cond result False
# is cond true False
# odliczanie 5 do 0 :-12
# cond result False
# is cond true False
# odliczanie 5 do 0 :-13
# cond result False
# is cond true False
# odliczanie 5 do 0 :-14
# cond result False
# is cond true False
# odliczanie 5 do 0 :-15
# cond result False
# is cond true False
# odliczanie 5 do 0 :-16
# cond result False
# is cond true False
# odliczanie 5 do 0 :-17
# cond result False
# is cond true False
# odliczanie 5 do 0 :-18
# cond result False
# is cond true False
# odliczanie 5 do 0 :-19
# cond result False
# is cond true False
# odliczanie 5 do 0 :-20
# cond result False
# is cond true False
# odliczanie 5 do 0 :-21
# cond result False
# is cond true False
# odliczanie 5 do 0 :-22
# cond result False
# is cond true False
# odliczanie 5 do 0 :-23
# cond result False
# is cond true False
# odliczanie 5 do 0 :-24
# cond result False
# is cond true False
# odliczanie 5 do 0 :-25
# cond result False
# is cond true False
# odliczanie 5 do 0 :-26
# cond result False
# is cond true False
# odliczanie 5 do 0 :-27
# cond result False
# is cond true False
# odliczanie 5 do 0 :-28
# cond result False
# is cond true False
# odliczanie 5 do 0 :-29
# cond result False
# is cond true False
# odliczanie 5 do 0 :-30
# cond result False
# is cond true False
# odliczanie 5 do 0 :-31
# cond result False
# is cond true False
# odliczanie 5 do 0 :-32
# cond result False
# is cond true False
# odliczanie 5 do 0 :-33
# cond result False
# is cond true False
# odliczanie 5 do 0 :-34
# cond result False
# is cond true False
# odliczanie 5 do 0 :-35
# cond result False
# is cond true False
# odliczanie 5 do 0 :-36
# cond result False
# is cond true False
# odliczanie 5 do 0 :-37
# cond result False
# is cond true False
# odliczanie 5 do 0 :-38
# cond result False
# is cond true False
# odliczanie 5 do 0 :-39
# cond result False
# is cond true False
# odliczanie 5 do 0 :-40
# cond result False
# is cond true False
# odliczanie 5 do 0 :-41
# cond result False
# is cond true False
# odliczanie 5 do 0 :-42
# cond result False
# is cond true False
# odliczanie 5 do 0 :-43
# cond result False
# is cond true False
# odliczanie 5 do 0 :-44
# cond result False
# is cond true False
# odliczanie 5 do 0 :-45
# cond result False
# is cond true False
# odliczanie 5 do 0 :-46
# cond result False
# is cond true False
# odliczanie 5 do 0 :-47
# cond result False
# is cond true False
# odliczanie 5 do 0 :-48
# cond result False
# is cond true False
# odliczanie 5 do 0 :-49
# cond result False
# is cond true False
# odliczanie 5 do 0 :-50
# cond result False
# is cond true False
# odliczanie 5 do 0 :-51
# cond result False
# is cond true False
# odliczanie 5 do 0 :-52
# cond result False
# is cond true False
# odliczanie 5 do 0 :-53
# cond result False
# is cond true False
# odliczanie 5 do 0 :-54
# cond result False
# is cond true False
# odliczanie 5 do 0 :-55
# cond result False
# is cond true False
# odliczanie 5 do 0 :-56
# cond result False
# is cond true False
# odliczanie 5 do 0 :-57
# cond result False
# is cond true False
# odliczanie 5 do 0 :-58
# cond result False
# is cond true False
# odliczanie 5 do 0 :-59
# cond result False
# is cond true False
# odliczanie 5 do 0 :-60
# cond result False
# is cond true False
# odliczanie 5 do 0 :-61
# cond result False
# is cond true False
# odliczanie 5 do 0 :-62
# cond result False
# is cond true False
# odliczanie 5 do 0 :-63
# cond result False
# is cond true False
# odliczanie 5 do 0 :-64
# cond result False
# is cond true False
# odliczanie 5 do 0 :-65
# cond result False
# is cond true False
# odliczanie 5 do 0 :-66
# cond result False
# is cond true False
# odliczanie 5 do 0 :-67
# cond result False
# is cond true False
# odliczanie 5 do 0 :-68
# cond result False
# is cond true False
# odliczanie 5 do 0 :-69
# cond result False
# is cond true False
# odliczanie 5 do 0 :-70
# cond result False
# is cond true False
# odliczanie 5 do 0 :-71
# cond result False
# is cond true False
# odliczanie 5 do 0 :-72
# cond result False
# is cond true False
# odliczanie 5 do 0 :-73
# cond result False
# is cond true False
# odliczanie 5 do 0 :-74
# cond result False
# is cond true False
# odliczanie 5 do 0 :-75
# cond result False
# is cond true False
# odliczanie 5 do 0 :-76
# cond result False
# is cond true False
# odliczanie 5 do 0 :-77
# cond result False
# is cond true False
# odliczanie 5 do 0 :-78
# cond result False
# is cond true False
# odliczanie 5 do 0 :-79
# cond result False
# is cond true False
# odliczanie 5 do 0 :-80
# cond result False
# is cond true False
# odliczanie 5 do 0 :-81
# cond result False
# is cond true False
# odliczanie 5 do 0 :-82
# cond result False
# is cond true False
# odliczanie 5 do 0 :-83
# cond result False
# is cond true False
# odliczanie 5 do 0 :-84
# cond result False
# is cond true False
# odliczanie 5 do 0 :-85
# cond result False
# is cond true False
# odliczanie 5 do 0 :-86
# cond result False
# is cond true False
# odliczanie 5 do 0 :-87
# cond result False
# is cond true False
# odliczanie 5 do 0 :-88
# cond result False
# is cond true False
# odliczanie 5 do 0 :-89
# cond result False
# is cond true False
# odliczanie 5 do 0 :-90
# cond result False
# is cond true False
# odliczanie 5 do 0 :-91
# cond result False
# is cond true False
# odliczanie 5 do 0 :-92
# cond result False
# is cond true False
# odliczanie 5 do 0 :-93
# cond result False
# is cond true False
# odliczanie 5 do 0 :-94
# cond result False
# is cond true False
# odliczanie 5 do 0 :-95
# cond result False
# is cond true False
# odliczanie 5 do 0 :-96
# cond result False
# is cond true False
# odliczanie 5 do 0 :-97
# cond result False
# is cond true False
# odliczanie 5 do 0 :-98
# cond result False
# is cond true False
# odliczanie 5 do 0 :-99
# cond result False
# is cond true False
# odliczanie 5 do 0 :-100
# cond result False
# is cond true False
# odliczanie 5 do 0 :-101
# cond result False
# is cond true False
# odliczanie 5 do 0 :-102
# cond result False
# is cond true False
# odliczanie 5 do 0 :-103
# cond result False
# is cond true False
# odliczanie 5 do 0 :-104
# cond result False
# is cond true False
# odliczanie 5 do 0 :-105
# cond result False
# is cond true False
# odliczanie 5 do 0 :-106
# cond result False
# is cond true False
# odliczanie 5 do 0 :-107
# cond result False
# is cond true False
# odliczanie 5 do 0 :-108
# cond result False
# is cond true False
# odliczanie 5 do 0 :-109
# cond result False
# is cond true False
# odliczanie 5 do 0 :-110
# cond result False
# is cond true False
# odliczanie 5 do 0 :-111
# cond result False
# is cond true False
# odliczanie 5 do 0 :-112
# cond result False
# is cond true False
# odliczanie 5 do 0 :-113
# cond result False
# is cond true False
# odliczanie 5 do 0 :-114
# cond result False
# is cond true False
# odliczanie 5 do 0 :-115
# cond result False
# is cond true False
# odliczanie 5 do 0 :-116
# cond result False
# is cond true False
# odliczanie 5 do 0 :-117
# cond result False
# is cond true False
# odliczanie 5 do 0 :-118
# cond result False
# is cond true False
# odliczanie 5 do 0 :-119
# cond result False
# is cond true False
# odliczanie 5 do 0 :-120
# cond result False
# is cond true False
# odliczanie 5 do 0 :-121
# cond result False
# is cond true False
# odliczanie 5 do 0 :-122
# cond result False
# is cond true False
# odliczanie 5 do 0 :-123
# cond result False
# is cond true False
# odliczanie 5 do 0 :-124
# cond result False
# is cond true False
# odliczanie 5 do 0 :-125
# cond result False
# is cond true False
# odliczanie 5 do 0 :-126
# cond result False
# is cond true False
# odliczanie 5 do 0 :-127
# cond result False
# is cond true False
# odliczanie 5 do 0 :-128
# cond result False
# is cond true False
# odliczanie 5 do 0 :-129
# cond result False
# is cond true False
# odliczanie 5 do 0 :-130
# cond result False
# is cond true False
# odliczanie 5 do 0 :-131
# cond result False
# is cond true False
# odliczanie 5 do 0 :-132
# cond result False
# is cond true False
# odliczanie 5 do 0 :-133
# cond result False
# is cond true False
# odliczanie 5 do 0 :-134
# cond result False
# is cond true False
# odliczanie 5 do 0 :-135
# cond result False
# is cond true False
# odliczanie 5 do 0 :-136
# cond result False
# is cond true False
# odliczanie 5 do 0 :-137
# cond result False
# is cond true False
# odliczanie 5 do 0 :-138
# cond result False
# is cond true False
# odliczanie 5 do 0 :-139
# cond result False
# is cond true False
# odliczanie 5 do 0 :-140
# cond result False
# is cond true False
# odliczanie 5 do 0 :-141
# cond result False
# is cond true False
# odliczanie 5 do 0 :-142
# cond result False
# is cond true False
# odliczanie 5 do 0 :-143
# cond result False
# is cond true False
# odliczanie 5 do 0 :-144
# cond result False
# is cond true False
# odliczanie 5 do 0 :-145
# cond result False
# is cond true False
# odliczanie 5 do 0 :-146
# cond result False
# is cond true False
# odliczanie 5 do 0 :-147
# cond result False
# is cond true False
# odliczanie 5 do 0 :-148
# cond result False
# is cond true False
# odliczanie 5 do 0 :-149
# cond result False
# is cond true False
# odliczanie 5 do 0 :-150
# cond result False
# is cond true False
# odliczanie 5 do 0 :-151
# cond result False
# is cond true False
# odliczanie 5 do 0 :-152
# cond result False
# is cond true False
# odliczanie 5 do 0 :-153
# cond result False
# is cond true False
# odliczanie 5 do 0 :-154
# cond result False
# is cond true False
# odliczanie 5 do 0 :-155
# cond result False
# is cond true False
# odliczanie 5 do 0 :-156
# cond result False
# is cond true False
# odliczanie 5 do 0 :-157
# cond result False
# is cond true False
# odliczanie 5 do 0 :-158
# cond result False
# is cond true False
# odliczanie 5 do 0 :-159
# cond result False
# is cond true False
# odliczanie 5 do 0 :-160
# cond result False
# is cond true False
# odliczanie 5 do 0 :-161
# cond result False
# is cond true False
# odliczanie 5 do 0 :-162
# cond result False
# is cond true False
# odliczanie 5 do 0 :-163
# cond result False
# is cond true False
# odliczanie 5 do 0 :-164
# cond result False
# is cond true False
# odliczanie 5 do 0 :-165
# cond result False
# is cond true False
# odliczanie 5 do 0 :-166
# cond result False
# is cond true False
# odliczanie 5 do 0 :-167
# cond result False
# is cond true False
# odliczanie 5 do 0 :-168
# cond result False
# is cond true False
# odliczanie 5 do 0 :-169
# cond result False
# is cond true False
# odliczanie 5 do 0 :-170
# cond result False
# is cond true False
# odliczanie 5 do 0 :-171
# cond result False
# is cond true False
# odliczanie 5 do 0 :-172
# cond result False
# is cond true False
# odliczanie 5 do 0 :-173
# cond result False
# is cond true False
# odliczanie 5 do 0 :-174
# cond result False
# is cond true False
# odliczanie 5 do 0 :-175
# cond result False
# is cond true False
# odliczanie 5 do 0 :-176
# cond result False
# is cond true False
# odliczanie 5 do 0 :-177
# cond result False
# is cond true False
# odliczanie 5 do 0 :-178
# cond result False
# is cond true False
# odliczanie 5 do 0 :-179
# cond result False
# is cond true False
# odliczanie 5 do 0 :-180
# cond result False
# is cond true False
# odliczanie 5 do 0 :-181
# cond result False
# is cond true False
# odliczanie 5 do 0 :-182
# cond result False
# is cond true False
# odliczanie 5 do 0 :-183
# cond result False
# is cond true False
# odliczanie 5 do 0 :-184
# cond result False
# is cond true False
# odliczanie 5 do 0 :-185
# cond result False
# is cond true False
# odliczanie 5 do 0 :-186
# cond result False
# is cond true False
# odliczanie 5 do 0 :-187
# cond result False
# is cond true False
# odliczanie 5 do 0 :-188
# cond result False
# is cond true False
# odliczanie 5 do 0 :-189
# cond result False
# is cond true False
# odliczanie 5 do 0 :-190
# cond result False
# is cond true False
# odliczanie 5 do 0 :-191
# cond result False
# is cond true False
# odliczanie 5 do 0 :-192
# cond result False
# is cond true False
# odliczanie 5 do 0 :-193
# cond result False
# is cond true False
# odliczanie 5 do 0 :-194
# cond result False
# is cond true False
# odliczanie 5 do 0 :-195
# cond result False
# is cond true False
# odliczanie 5 do 0 :-196
# cond result False
# is cond true False
# odliczanie 5 do 0 :-197
# cond result False
# is cond true False
# odliczanie 5 do 0 :-198
# cond result False
# is cond true False
# odliczanie 5 do 0 :-199
# cond result False
# is cond true False
# odliczanie 5 do 0 :-200
# cond result False
# is cond true False
# odliczanie 5 do 0 :-201
# cond result False
# is cond true False
# odliczanie 5 do 0 :-202
# cond result False
# is cond true False
# odliczanie 5 do 0 :-203
# cond result False
# is cond true False
# odliczanie 5 do 0 :-204
# cond result False
# is cond true False
# odliczanie 5 do 0 :-205
# cond result False
# is cond true False
# odliczanie 5 do 0 :-206
# cond result False
# is cond true False
# odliczanie 5 do 0 :-207
# cond result False
# is cond true False
# odliczanie 5 do 0 :-208
# cond result False
# is cond true False
# odliczanie 5 do 0 :-209
# cond result False
# is cond true False
# odliczanie 5 do 0 :-210
# cond result False
# is cond true False
# odliczanie 5 do 0 :-211
# cond result False
# is cond true False
# odliczanie 5 do 0 :-212
# cond result False
# is cond true False
# odliczanie 5 do 0 :-213
# cond result False
# is cond true False
# odliczanie 5 do 0 :-214
# cond result False
# is cond true False
# odliczanie 5 do 0 :-215
# cond result False
# is cond true False
# odliczanie 5 do 0 :-216
# cond result False
# is cond true False
# odliczanie 5 do 0 :-217
# cond result False
# is cond true False
# odliczanie 5 do 0 :-218
# cond result False
# is cond true False
# odliczanie 5 do 0 :-219
# cond result False
# is cond true False
# odliczanie 5 do 0 :-220
# cond result False
# is cond true False
# odliczanie 5 do 0 :-221
# cond result False
# is cond true False
# odliczanie 5 do 0 :-222
# cond result False
# is cond true False
# odliczanie 5 do 0 :-223
# cond result False
# is cond true False
# odliczanie 5 do 0 :-224
# cond result False
# is cond true False
# odliczanie 5 do 0 :-225
# cond result False
# is cond true False
# odliczanie 5 do 0 :-226
# cond result False
# is cond true False
# odliczanie 5 do 0 :-227
# cond result False
# is cond true False
# odliczanie 5 do 0 :-228
# cond result False
# is cond true False
# odliczanie 5 do 0 :-229
# cond result False
# is cond true False
# odliczanie 5 do 0 :-230
# cond result False
# is cond true False
# odliczanie 5 do 0 :-231
# cond result False
# is cond true False
# odliczanie 5 do 0 :-232
# cond result False
# is cond true False
# odliczanie 5 do 0 :-233
# cond result False
# is cond true False
# odliczanie 5 do 0 :-234
# cond result False
# is cond true False
# odliczanie 5 do 0 :-235
# cond result False
# is cond true False
# odliczanie 5 do 0 :-236
# cond result False
# is cond true False
# odliczanie 5 do 0 :-237
# cond result False
# is cond true False
# odliczanie 5 do 0 :-238
# cond result False
# is cond true False
# odliczanie 5 do 0 :-239
# cond result False
# is cond true False
# odliczanie 5 do 0 :-240
# cond result False
# is cond true False
# odliczanie 5 do 0 :-241
# cond result False
# is cond true False
# odliczanie 5 do 0 :-242
# cond result False
# is cond true False
# odliczanie 5 do 0 :-243
# cond result False
# is cond true False
# odliczanie 5 do 0 :-244
# cond result False
# is cond true False
# odliczanie 5 do 0 :-245
# cond result False
# is cond true False
# odliczanie 5 do 0 :-246
# cond result False
# is cond true False
# odliczanie 5 do 0 :-247
# cond result False
# is cond true False
# odliczanie 5 do 0 :-248
# cond result False
# is cond true False
# odliczanie 5 do 0 :-249
# cond result False
# is cond true False
# odliczanie 5 do 0 :-250
# cond result False
# is cond true False
# odliczanie 5 do 0 :-251
# cond result False
# is cond true False
# odliczanie 5 do 0 :-252
# cond result False
# is cond true False
# odliczanie 5 do 0 :-253
# cond result False
# is cond true False
# odliczanie 5 do 0 :-254
# cond result False
# is cond true False
# odliczanie 5 do 0 :-255
# cond result False
# is cond true False
# odliczanie 5 do 0 :-256
# cond result False
# is cond true False
# odliczanie 5 do 0 :-257
# cond result False
# is cond true False
# odliczanie 5 do 0 :-258
# cond result False
# is cond true False
# odliczanie 5 do 0 :-259
# cond result False
# is cond true False
# odliczanie 5 do 0 :-260
# cond result False
# is cond true False
# odliczanie 5 do 0 :-261
# cond result False
# is cond true False
# odliczanie 5 do 0 :-262
# cond result False
# is cond true False
# odliczanie 5 do 0 :-263
# cond result False
# is cond true False
# odliczanie 5 do 0 :-264
# cond result False
# is cond true False
# odliczanie 5 do 0 :-265
# cond result False
# is cond true False
# odliczanie 5 do 0 :-266
# cond result False
# is cond true False
# odliczanie 5 do 0 :-267
# cond result False
# is cond true False
# odliczanie 5 do 0 :-268
# cond result False
# is cond true False
# odliczanie 5 do 0 :-269
# cond result False
# is cond true False
# odliczanie 5 do 0 :-270
# cond result False
# is cond true False
# odliczanie 5 do 0 :-271
# cond result False
# is cond true False
# odliczanie 5 do 0 :-272
# cond result False
# is cond true False
# odliczanie 5 do 0 :-273
# cond result False
# is cond true False
# odliczanie 5 do 0 :-274
# cond result False
# is cond true False
# odliczanie 5 do 0 :-275
# cond result False
# is cond true False
# odliczanie 5 do 0 :-276
# cond result False
# is cond true False
# odliczanie 5 do 0 :-277
# cond result False
# is cond true False
# odliczanie 5 do 0 :-278
# cond result False
# is cond true False
# odliczanie 5 do 0 :-279
# cond result False
# is cond true False
# odliczanie 5 do 0 :-280
# cond result False
# is cond true False
# odliczanie 5 do 0 :-281
# cond result False
# is cond true False
# odliczanie 5 do 0 :-282
# cond result False
# is cond true False
# odliczanie 5 do 0 :-283
# cond result False
# is cond true False
# odliczanie 5 do 0 :-284
# cond result False
# is cond true False
# odliczanie 5 do 0 :-285
# cond result False
# is cond true False
# odliczanie 5 do 0 :-286
# cond result False
# is cond true False
# odliczanie 5 do 0 :-287
# cond result False
# is cond true False
# odliczanie 5 do 0 :-288
# cond result False
# is cond true False
# odliczanie 5 do 0 :-289
# cond result False
# is cond true False
# odliczanie 5 do 0 :-290
# cond result False
# is cond true False
# odliczanie 5 do 0 :-291
# cond result False
# is cond true False
# odliczanie 5 do 0 :-292
# cond result False
# is cond true False
# odliczanie 5 do 0 :-293
# cond result False
# is cond true False
# odliczanie 5 do 0 :-294
# cond result False
# is cond true False
# odliczanie 5 do 0 :-295
# cond result False
# is cond true False
# odliczanie 5 do 0 :-296
# cond result False
# is cond true False
# odliczanie 5 do 0 :-297
# cond result False
# is cond true False
# odliczanie 5 do 0 :-298
# cond result False
# is cond true False
# odliczanie 5 do 0 :-299
# cond result False
# is cond true False
# odliczanie 5 do 0 :-300
# cond result False
# is cond true False
# odliczanie 5 do 0 :-301
# cond result False
# is cond true False
# odliczanie 5 do 0 :-302
# cond result False
# is cond true False
# odliczanie 5 do 0 :-303
# cond result False
# is cond true False
# odliczanie 5 do 0 :-304
# cond result False
# is cond true False
# odliczanie 5 do 0 :-305
# cond result False
# is cond true False
# odliczanie 5 do 0 :-306
# cond result False
# is cond true False
# odliczanie 5 do 0 :-307
# cond result False
# is cond true False
# odliczanie 5 do 0 :-308
# cond result False
# is cond true False
# odliczanie 5 do 0 :-309
# cond result False
# is cond true False
# odliczanie 5 do 0 :-310
# cond result False
# is cond true False
# odliczanie 5 do 0 :-311
# cond result False
# is cond true False
# odliczanie 5 do 0 :-312
# cond result False
# is cond true False
# odliczanie 5 do 0 :-313
# cond result False
# is cond true False
# odliczanie 5 do 0 :-314
# cond result False
# is cond true False
# odliczanie 5 do 0 :-315
# cond result False
# is cond true False
# odliczanie 5 do 0 :-316
# cond result False
# is cond true False
# odliczanie 5 do 0 :-317
# cond result False
# is cond true False
# odliczanie 5 do 0 :-318
# cond result False
# is cond true False
# odliczanie 5 do 0 :-319
# cond result False
# is cond true False
# odliczanie 5 do 0 :-320
# cond result False
# is cond true False
# odliczanie 5 do 0 :-321
# cond result False
# is cond true False
# odliczanie 5 do 0 :-322
# cond result False
# is cond true False
# odliczanie 5 do 0 :-323
# cond result False
# is cond true False
# odliczanie 5 do 0 :-324
# cond result False
# is cond true False
# odliczanie 5 do 0 :-325
# cond result False
# is cond true False
# odliczanie 5 do 0 :-326
# cond result False
# is cond true False
# odliczanie 5 do 0 :-327
# cond result False
# is cond true False
# odliczanie 5 do 0 :-328
# cond result False
# is cond true False
# odliczanie 5 do 0 :-329
# cond result False
# is cond true False
# odliczanie 5 do 0 :-330
# cond result False
# is cond true False
# odliczanie 5 do 0 :-331
# cond result False
# is cond true False
# odliczanie 5 do 0 :-332
# cond result False
# is cond true False
# odliczanie 5 do 0 :-333
# cond result False
# is cond true False
# odliczanie 5 do 0 :-334
# cond result False
# is cond true False
# odliczanie 5 do 0 :-335
# cond result False
# is cond true False
# odliczanie 5 do 0 :-336
# cond result False
# is cond true False
# odliczanie 5 do 0 :-337
# cond result False
# is cond true False
# odliczanie 5 do 0 :-338
# cond result False
# is cond true False
# odliczanie 5 do 0 :-339
# cond result False
# is cond true False
# odliczanie 5 do 0 :-340
# cond result False
# is cond true False
# odliczanie 5 do 0 :-341
# cond result False
# is cond true False
# odliczanie 5 do 0 :-342
# cond result False
# is cond true False
# odliczanie 5 do 0 :-343
# cond result False
# is cond true False
# odliczanie 5 do 0 :-344
# cond result False
# is cond true False
# odliczanie 5 do 0 :-345
# cond result False
# is cond true False
# odliczanie 5 do 0 :-346
# cond result False
# is cond true False
# odliczanie 5 do 0 :-347
# cond result False
# is cond true False
# odliczanie 5 do 0 :-348
# cond result False
# is cond true False
# odliczanie 5 do 0 :-349
# cond result False
# is cond true False
# odliczanie 5 do 0 :-350
# cond result False
# is cond true False
# odliczanie 5 do 0 :-351
# cond result False
# is cond true False
# odliczanie 5 do 0 :-352
# cond result False
# is cond true False
# odliczanie 5 do 0 :-353
# cond result False
# is cond true False
# odliczanie 5 do 0 :-354
# cond result False
# is cond true False
# odliczanie 5 do 0 :-355
# cond result False
# is cond true False
# odliczanie 5 do 0 :-356
# cond result False
# is cond true False
# odliczanie 5 do 0 :-357
# cond result False
# is cond true False
# odliczanie 5 do 0 :-358
# cond result False
# is cond true False
# odliczanie 5 do 0 :-359
# cond result False
# is cond true False
# odliczanie 5 do 0 :-360
# cond result False
# is cond true False
# odliczanie 5 do 0 :-361
# cond result False
# is cond true False
# odliczanie 5 do 0 :-362
# cond result False
# is cond true False
# odliczanie 5 do 0 :-363
# cond result False
# is cond true False
# odliczanie 5 do 0 :-364
# cond result False
# is cond true False
# odliczanie 5 do 0 :-365
# cond result False
# is cond true False
# odliczanie 5 do 0 :-366
# cond result False
# is cond true False
# odliczanie 5 do 0 :-367
# cond result False
# is cond true False
# odliczanie 5 do 0 :-368
# cond result False
# is cond true False
# odliczanie 5 do 0 :-369
# cond result False
# is cond true False
# odliczanie 5 do 0 :-370
# cond result False
# is cond true False
# odliczanie 5 do 0 :-371
# cond result False
# is cond true False
# odliczanie 5 do 0 :-372
# cond result False
# is cond true False
# odliczanie 5 do 0 :-373
# cond result False
# is cond true False
# odliczanie 5 do 0 :-374
# cond result False
# is cond true False
# odliczanie 5 do 0 :-375
# cond result False
# is cond true False
# odliczanie 5 do 0 :-376
# cond result False
# is cond true False
# odliczanie 5 do 0 :-377
# cond result False
# is cond true False
# odliczanie 5 do 0 :-378
# cond result False
# is cond true False
# odliczanie 5 do 0 :-379
# cond result False
# is cond true False
# odliczanie 5 do 0 :-380
# cond result False
# is cond true False
# odliczanie 5 do 0 :-381
# cond result False
# is cond true False
# odliczanie 5 do 0 :-382
# cond result False
# is cond true False
# odliczanie 5 do 0 :-383
# cond result False
# is cond true False
# odliczanie 5 do 0 :-384
# cond result False
# is cond true False
# odliczanie 5 do 0 :-385
# cond result False
# is cond true False
# odliczanie 5 do 0 :-386
# cond result False
# is cond true False
# odliczanie 5 do 0 :-387
# cond result False
# is cond true False
# odliczanie 5 do 0 :-388
# cond result False
# is cond true False
# odliczanie 5 do 0 :-389
# cond result False
# is cond true False
# odliczanie 5 do 0 :-390
# cond result False
# is cond true False
# odliczanie 5 do 0 :-391
# cond result False
# is cond true False
# odliczanie 5 do 0 :-392
# cond result False
# is cond true False
# odliczanie 5 do 0 :-393
# cond result False
# is cond true False
# odliczanie 5 do 0 :-394
# cond result False
# is cond true False
# odliczanie 5 do 0 :-395
# cond result False
# is cond true False
# odliczanie 5 do 0 :-396
# cond result False
# is cond true False
# odliczanie 5 do 0 :-397
# cond result False
# is cond true False
# odliczanie 5 do 0 :-398
# cond result False
# is cond true False
# odliczanie 5 do 0 :-399
# cond result False
# is cond true False
# odliczanie 5 do 0 :-400
# cond result False
# is cond true False
# odliczanie 5 do 0 :-401
# cond result False
# is cond true False
# odliczanie 5 do 0 :-402
# cond result False
# is cond true False
# odliczanie 5 do 0 :-403
# cond result False
# is cond true False
# odliczanie 5 do 0 :-404
# cond result False
# is cond true False
# odliczanie 5 do 0 :-405
# cond result False
# is cond true False
# odliczanie 5 do 0 :-406
# cond result False
# is cond true False
# odliczanie 5 do 0 :-407
# cond result False
# is cond true False
# odliczanie 5 do 0 :-408
# cond result False
# is cond true False
# odliczanie 5 do 0 :-409
# cond result False
# is cond true False
# odliczanie 5 do 0 :-410
# cond result False
# is cond true False
# odliczanie 5 do 0 :-411
# cond result False
# is cond true False
# odliczanie 5 do 0 :-412
# cond result False
# is cond true False
# odliczanie 5 do 0 :-413
# cond result False
# is cond true False
# odliczanie 5 do 0 :-414
# cond result False
# is cond true False
# odliczanie 5 do 0 :-415
# cond result False
# is cond true False
# odliczanie 5 do 0 :-416
# cond result False
# is cond true False
# odliczanie 5 do 0 :-417
# cond result False
# is cond true False
# odliczanie 5 do 0 :-418
# cond result False
# is cond true False
# odliczanie 5 do 0 :-419
# cond result False
# is cond true False
# odliczanie 5 do 0 :-420
# cond result False
# is cond true False
# odliczanie 5 do 0 :-421
# cond result False
# is cond true False
# odliczanie 5 do 0 :-422
# cond result False
# is cond true False
# odliczanie 5 do 0 :-423
# cond result False
# is cond true False
# odliczanie 5 do 0 :-424
# cond result False
# is cond true False
# odliczanie 5 do 0 :-425
# cond result False
# is cond true False
# odliczanie 5 do 0 :-426
# cond result False
# is cond true False
# odliczanie 5 do 0 :-427
# cond result False
# is cond true False
# odliczanie 5 do 0 :-428
# cond result False
# is cond true False
# odliczanie 5 do 0 :-429
# cond result False
# is cond true False
# odliczanie 5 do 0 :-430
# cond result False
# is cond true False
# odliczanie 5 do 0 :-431
# cond result False
# is cond true False
# odliczanie 5 do 0 :-432
# cond result False
# is cond true False
# odliczanie 5 do 0 :-433
# cond result False
# is cond true False
# odliczanie 5 do 0 :-434
# cond result False
# is cond true False
# odliczanie 5 do 0 :-435
# cond result False
# is cond true False
# odliczanie 5 do 0 :-436
# cond result False
# is cond true False
# odliczanie 5 do 0 :-437
# cond result False
# is cond true False
# odliczanie 5 do 0 :-438
# cond result False
# is cond true False
# odliczanie 5 do 0 :-439
# cond result False
# is cond true False
# odliczanie 5 do 0 :-440
# cond result False
# is cond true False
# odliczanie 5 do 0 :-441
# cond result False
# is cond true False
# odliczanie 5 do 0 :-442
# cond result False
# is cond true False
# odliczanie 5 do 0 :-443
# cond result False
# is cond true False
# odliczanie 5 do 0 :-444
# cond result False
# is cond true False
# odliczanie 5 do 0 :-445
# cond result False
# is cond true False
# odliczanie 5 do 0 :-446
# cond result False
# is cond true False
# odliczanie 5 do 0 :-447
# cond result False
# is cond true False
# odliczanie 5 do 0 :-448
# cond result False
# is cond true False
# odliczanie 5 do 0 :-449
# cond result False
# is cond true False
# odliczanie 5 do 0 :-450
# cond result False
# is cond true False
# odliczanie 5 do 0 :-451
# cond result False
# is cond true False
# odliczanie 5 do 0 :-452
# cond result False
# is cond true False
# odliczanie 5 do 0 :-453
# cond result False
# is cond true False
# odliczanie 5 do 0 :-454
# cond result False
# is cond true False
# odliczanie 5 do 0 :-455
# cond result False
# is cond true False
# odliczanie 5 do 0 :-456
# cond result False
# is cond true False
# odliczanie 5 do 0 :-457
# cond result False
# is cond true False
# odliczanie 5 do 0 :-458
# cond result False
# is cond true False
# odliczanie 5 do 0 :-459
# cond result False
# is cond true False
# odliczanie 5 do 0 :-460
# cond result False
# is cond true False
# odliczanie 5 do 0 :-461
# cond result False
# is cond true False
# odliczanie 5 do 0 :-462
# cond result False
# is cond true False
# odliczanie 5 do 0 :-463
# cond result False
# is cond true False
# odliczanie 5 do 0 :-464
# cond result False
# is cond true False
# odliczanie 5 do 0 :-465
# cond result False
# is cond true False
# odliczanie 5 do 0 :-466
# cond result False
# is cond true False
# odliczanie 5 do 0 :-467
# cond result False
# is cond true False
# odliczanie 5 do 0 :-468
# cond result False
# is cond true False
# odliczanie 5 do 0 :-469
# cond result False
# is cond true False
# odliczanie 5 do 0 :-470
# cond result False
# is cond true False
# odliczanie 5 do 0 :-471
# cond result False
# is cond true False
# odliczanie 5 do 0 :-472
# cond result False
# is cond true False
# odliczanie 5 do 0 :-473
# cond result False
# is cond true False
# odliczanie 5 do 0 :-474
# cond result False
# is cond true False
# odliczanie 5 do 0 :-475
# cond result False
# is cond true False
# odliczanie 5 do 0 :-476
# cond result False
# is cond true False
# odliczanie 5 do 0 :-477
# cond result False
# is cond true False
# odliczanie 5 do 0 :-478
# cond result False
# is cond true False
# odliczanie 5 do 0 :-479
# cond result False
# is cond true False
# odliczanie 5 do 0 :-480
# cond result False
# is cond true False
# odliczanie 5 do 0 :-481
# cond result False
# is cond true False
# odliczanie 5 do 0 :-482
# cond result False
# is cond true False
# odliczanie 5 do 0 :-483
# cond result False
# is cond true False
# odliczanie 5 do 0 :-484
# cond result False
# is cond true False
# odliczanie 5 do 0 :-485
# cond result False
# is cond true False
# odliczanie 5 do 0 :-486
# cond result False
# is cond true False
# odliczanie 5 do 0 :-487
# cond result False
# is cond true False
# odliczanie 5 do 0 :-488
# cond result False
# is cond true False
# odliczanie 5 do 0 :-489
# cond result False
# is cond true False
# odliczanie 5 do 0 :-490
# cond result False
# is cond true False
# odliczanie 5 do 0 :-491
# cond result False
# is cond true False
# odliczanie 5 do 0 :-492
# cond result False
# is cond true False
# odliczanie 5 do 0 :-493
# cond result False
# is cond true False
# odliczanie 5 do 0 :-494
# cond result False
# is cond true False
# odliczanie 5 do 0 :-495
# cond result False
# is cond true False
# odliczanie 5 do 0 :-496
# cond result False
# is cond true False
# odliczanie 5 do 0 :-497
# cond result False
# is cond true False
# odliczanie 5 do 0 :-498
# cond result False
# is cond true False
# odliczanie 5 do 0 :-499
# cond result False
# is cond true False
# odliczanie 5 do 0 :-500
# cond result False
# is cond true False
# odliczanie 5 do 0 :-501
# cond result False
# is cond true False
# odliczanie 5 do 0 :-502
# cond result False
# is cond true False
# odliczanie 5 do 0 :-503
# cond result False
# is cond true False
# odliczanie 5 do 0 :-504
# cond result False
# is cond true False
# odliczanie 5 do 0 :-505
# cond result False
# is cond true False
# odliczanie 5 do 0 :-506
# cond result False
# is cond true False
# odliczanie 5 do 0 :-507
# cond result False
# is cond true False
# odliczanie 5 do 0 :-508
# cond result False
# is cond true False
# odliczanie 5 do 0 :-509
# cond result False
# is cond true False
# odliczanie 5 do 0 :-510
# cond result False
# is cond true False
# odliczanie 5 do 0 :-511
# cond result False
# is cond true False
# odliczanie 5 do 0 :-512
# cond result False
# is cond true False
# odliczanie 5 do 0 :-513
# cond result False
# is cond true False
# odliczanie 5 do 0 :-514
# cond result False
# is cond true False
# odliczanie 5 do 0 :-515
# cond result False
# is cond true False
# odliczanie 5 do 0 :-516
# cond result False
# is cond true False
# odliczanie 5 do 0 :-517
# cond result False
# is cond true False
# odliczanie 5 do 0 :-518
# cond result False
# is cond true False
# odliczanie 5 do 0 :-519
# cond result False
# is cond true False
# odliczanie 5 do 0 :-520
# cond result False
# is cond true False
# odliczanie 5 do 0 :-521
# cond result False
# is cond true False
# odliczanie 5 do 0 :-522
# cond result False
# is cond true False
# odliczanie 5 do 0 :-523
# cond result False
# is cond true False
# odliczanie 5 do 0 :-524
# cond result False
# is cond true False
# odliczanie 5 do 0 :-525
# cond result False
# is cond true False
# odliczanie 5 do 0 :-526
# cond result False
# is cond true False
# odliczanie 5 do 0 :-527
# cond result False
# is cond true False
# odliczanie 5 do 0 :-528
# cond result False
# is cond true False
# odliczanie 5 do 0 :-529
# cond result False
# is cond true False
# odliczanie 5 do 0 :-530
# cond result False
# is cond true False
# odliczanie 5 do 0 :-531
# cond result False
# is cond true False
# odliczanie 5 do 0 :-532
# cond result False
# is cond true False
# odliczanie 5 do 0 :-533
# cond result False
# is cond true False
# odliczanie 5 do 0 :-534
# cond result False
# is cond true False
# odliczanie 5 do 0 :-535
# cond result False
# is cond true False
# odliczanie 5 do 0 :-536
# cond result False
# is cond true False
# odliczanie 5 do 0 :-537
# cond result False
# is cond true False
# odliczanie 5 do 0 :-538
# cond result False
# is cond true False
# odliczanie 5 do 0 :-539
# cond result False
# is cond true False
# odliczanie 5 do 0 :-540
# cond result False
# is cond true False
# odliczanie 5 do 0 :-541
# cond result False
# is cond true False
# odliczanie 5 do 0 :-542
# cond result False
# is cond true False
# odliczanie 5 do 0 :-543
# cond result False
# is cond true False
# odliczanie 5 do 0 :-544
# cond result False
# is cond true False
# odliczanie 5 do 0 :-545
# cond result False
# is cond true False
# odliczanie 5 do 0 :-546
# cond result False
# is cond true False
# odliczanie 5 do 0 :-547
# cond result False
# is cond true False
# odliczanie 5 do 0 :-548
# cond result False
# is cond true False
# odliczanie 5 do 0 :-549
# cond result False
# is cond true False
# odliczanie 5 do 0 :-550
# cond result False
# is cond true False
# odliczanie 5 do 0 :-551
# cond result False
# is cond true False
# odliczanie 5 do 0 :-552
# cond result False
# is cond true False
# odliczanie 5 do 0 :-553
# cond result False
# is cond true False
# odliczanie 5 do 0 :-554
# cond result False
# is cond true False
# odliczanie 5 do 0 :-555
# cond result False
# is cond true False
# odliczanie 5 do 0 :-556
# cond result False
# is cond true False
# odliczanie 5 do 0 :-557
# cond result False
# is cond true False
# odliczanie 5 do 0 :-558
# cond result False
# is cond true False
# odliczanie 5 do 0 :-559
# cond result False
# is cond true False
# odliczanie 5 do 0 :-560
# cond result False
# is cond true False
# odliczanie 5 do 0 :-561
# cond result False
# is cond true False
# odliczanie 5 do 0 :-562
# cond result False
# is cond true False
# odliczanie 5 do 0 :-563
# cond result False
# is cond true False
# odliczanie 5 do 0 :-564
# cond result False
# is cond true False
# odliczanie 5 do 0 :-565
# cond result False
# is cond true False
# odliczanie 5 do 0 :-566
# cond result False
# is cond true False
# odliczanie 5 do 0 :-567
# cond result False
# is cond true False
# odliczanie 5 do 0 :-568
# cond result False
# is cond true False
# odliczanie 5 do 0 :-569
# cond result False
# is cond true False
# odliczanie 5 do 0 :-570
# cond result False
# is cond true False
# odliczanie 5 do 0 :-571
# cond result False
# is cond true False
# odliczanie 5 do 0 :-572
# cond result False
# is cond true False
# odliczanie 5 do 0 :-573
# cond result False
# is cond true False
# odliczanie 5 do 0 :-574
# cond result False
# is cond true False
# odliczanie 5 do 0 :-575
# cond result False
# is cond true False
# odliczanie 5 do 0 :-576
# cond result False
# is cond true False
# odliczanie 5 do 0 :-577
# cond result False
# is cond true False
# odliczanie 5 do 0 :-578
# cond result False
# is cond true False
# odliczanie 5 do 0 :-579
# cond result False
# is cond true False
# odliczanie 5 do 0 :-580
# cond result False
# is cond true False
# odliczanie 5 do 0 :-581
# cond result False
# is cond true False
# odliczanie 5 do 0 :-582
# cond result False
# is cond true False
# odliczanie 5 do 0 :-583
# cond result False
# is cond true False
# odliczanie 5 do 0 :-584
# cond result False
# is cond true False
# odliczanie 5 do 0 :-585
# cond result False
# is cond true False
# odliczanie 5 do 0 :-586
# cond result False
# is cond true False
# odliczanie 5 do 0 :-587
# cond result False
# is cond true False
# odliczanie 5 do 0 :-588
# cond result False
# is cond true False
# odliczanie 5 do 0 :-589
# cond result False
# is cond true False
# odliczanie 5 do 0 :-590
# cond result False
# is cond true False
# odliczanie 5 do 0 :-591
# cond result False
# is cond true False
# odliczanie 5 do 0 :-592
# cond result False
# is cond true False
# odliczanie 5 do 0 :-593
# cond result False
# is cond true False
# odliczanie 5 do 0 :-594
# cond result False
# is cond true False
# odliczanie 5 do 0 :-595
# cond result False
# is cond true False
# odliczanie 5 do 0 :-596
# cond result False
# is cond true False
# odliczanie 5 do 0 :-597
# cond result False
# is cond true False
# odliczanie 5 do 0 :-598
# cond result False
# is cond true False
# odliczanie 5 do 0 :-599
# cond result False
# is cond true False
# odliczanie 5 do 0 :-600
# cond result False
# is cond true False
# odliczanie 5 do 0 :-601
# cond result False
# is cond true False
# odliczanie 5 do 0 :-602
# cond result False
# is cond true False
# odliczanie 5 do 0 :-603
# cond result False
# is cond true False
# odliczanie 5 do 0 :-604
# cond result False
# is cond true False
# odliczanie 5 do 0 :-605
# cond result False
# is cond true False
# odliczanie 5 do 0 :-606
# cond result False
# is cond true False
# odliczanie 5 do 0 :-607
# cond result False
# is cond true False
# odliczanie 5 do 0 :-608
# cond result False
# is cond true False
# odliczanie 5 do 0 :-609
# cond result False
# is cond true False
# odliczanie 5 do 0 :-610
# cond result False
# is cond true False
# odliczanie 5 do 0 :-611
# cond result False
# is cond true False
# odliczanie 5 do 0 :-612
# cond result False
# is cond true False
# odliczanie 5 do 0 :-613
# cond result False
# is cond true False
# odliczanie 5 do 0 :-614
# cond result False
# is cond true False
# odliczanie 5 do 0 :-615
# cond result False
# is cond true False
# odliczanie 5 do 0 :-616
# cond result False
# is cond true False
# odliczanie 5 do 0 :-617
# cond result False
# is cond true False
# odliczanie 5 do 0 :-618
# cond result False
# is cond true False
# odliczanie 5 do 0 :-619
# cond result False
# is cond true False
# odliczanie 5 do 0 :-620
# cond result False
# is cond true False
# odliczanie 5 do 0 :-621
# cond result False
# is cond true False
# odliczanie 5 do 0 :-622
# cond result False
# is cond true False
# odliczanie 5 do 0 :-623
# cond result False
# is cond true False
# odliczanie 5 do 0 :-624
# cond result False
# is cond true False
# odliczanie 5 do 0 :-625
# cond result False
# is cond true False
# odliczanie 5 do 0 :-626
# cond result False
# is cond true False
# odliczanie 5 do 0 :-627
# cond result False
# is cond true False
# odliczanie 5 do 0 :-628
# cond result False
# is cond true False
# odliczanie 5 do 0 :-629
# cond result False
# is cond true False
# odliczanie 5 do 0 :-630
# cond result False
# is cond true False
# odliczanie 5 do 0 :-631
# cond result False
# is cond true False
# odliczanie 5 do 0 :-632
# cond result False
# is cond true False
# odliczanie 5 do 0 :-633
# cond result False
# is cond true False
# odliczanie 5 do 0 :-634
# cond result False
# is cond true False
# odliczanie 5 do 0 :-635
# cond result False
# is cond true False
# odliczanie 5 do 0 :-636
# cond result False
# is cond true False
# odliczanie 5 do 0 :-637
# cond result False
# is cond true False
# odliczanie 5 do 0 :-638
# cond result False
# is cond true False
# odliczanie 5 do 0 :-639
# cond result False
# is cond true False
# odliczanie 5 do 0 :-640
# cond result False
# is cond true False
# odliczanie 5 do 0 :-641
# cond result False
# is cond true False
# odliczanie 5 do 0 :-642
# cond result False
# is cond true False
# odliczanie 5 do 0 :-643
# cond result False
# is cond true False
# odliczanie 5 do 0 :-644
# cond result False
# is cond true False
# odliczanie 5 do 0 :-645
# cond result False
# is cond true False
# odliczanie 5 do 0 :-646
# cond result False
# is cond true False
# odliczanie 5 do 0 :-647
# cond result False
# is cond true False
# odliczanie 5 do 0 :-648
# cond result False
# is cond true False
# odliczanie 5 do 0 :-649
# cond result False
# is cond true False
# odliczanie 5 do 0 :-650
# cond result False
# is cond true False
# odliczanie 5 do 0 :-651
# cond result False
# is cond true False
# odliczanie 5 do 0 :-652
# cond result False
# is cond true False
# odliczanie 5 do 0 :-653
# cond result False
# is cond true False
# odliczanie 5 do 0 :-654
# cond result False
# is cond true False
# odliczanie 5 do 0 :-655
# cond result False
# is cond true False
# odliczanie 5 do 0 :-656
# cond result False
# is cond true False
# odliczanie 5 do 0 :-657
# cond result False
# is cond true False
# odliczanie 5 do 0 :-658
# cond result False
# is cond true False
# odliczanie 5 do 0 :-659
# cond result False
# is cond true False
# odliczanie 5 do 0 :-660
# cond result False
# is cond true False
# odliczanie 5 do 0 :-661
# cond result False
# is cond true False
# odliczanie 5 do 0 :-662
# cond result False
# is cond true False
# odliczanie 5 do 0 :-663
# cond result False
# is cond true False
# odliczanie 5 do 0 :-664
# cond result False
# is cond true False
# odliczanie 5 do 0 :-665
# cond result False
# is cond true False
# odliczanie 5 do 0 :-666
# cond result False
# is cond true False
# odliczanie 5 do 0 :-667
# cond result False
# is cond true False
# odliczanie 5 do 0 :-668
# cond result False
# is cond true False
# odliczanie 5 do 0 :-669
# cond result False
# is cond true False
# odliczanie 5 do 0 :-670
# cond result False
# is cond true False
# odliczanie 5 do 0 :-671
# cond result False
# is cond true False
# odliczanie 5 do 0 :-672
# cond result False
# is cond true False
# odliczanie 5 do 0 :-673
# cond result False
# is cond true False
# odliczanie 5 do 0 :-674
# cond result False
# is cond true False
# odliczanie 5 do 0 :-675
# cond result False
# is cond true False
# odliczanie 5 do 0 :-676
# cond result False
# is cond true False
# odliczanie 5 do 0 :-677
# cond result False
# is cond true False
# odliczanie 5 do 0 :-678
# cond result False
# is cond true False
# odliczanie 5 do 0 :-679
# cond result False
# is cond true False
# odliczanie 5 do 0 :-680
# cond result False
# is cond true False
# odliczanie 5 do 0 :-681
# cond result False
# is cond true False
# odliczanie 5 do 0 :-682
# cond result False
# is cond true False
# odliczanie 5 do 0 :-683
# cond result False
# is cond true False
# odliczanie 5 do 0 :-684
# cond result False
# is cond true False
# odliczanie 5 do 0 :-685
# cond result False
# is cond true False
# odliczanie 5 do 0 :-686
# cond result False
# is cond true False
# odliczanie 5 do 0 :-687
# cond result False
# is cond true False
# odliczanie 5 do 0 :-688
# cond result False
# is cond true False
# odliczanie 5 do 0 :-689
# cond result False
# is cond true False
# odliczanie 5 do 0 :-690
# cond result False
# is cond true False
# odliczanie 5 do 0 :-691
# cond result False
# is cond true False
# odliczanie 5 do 0 :-692
# cond result False
# is cond true False
# odliczanie 5 do 0 :-693
# cond result False
# is cond true False
# odliczanie 5 do 0 :-694
# cond result False
# is cond true False
# odliczanie 5 do 0 :-695
# cond result False
# is cond true False
# odliczanie 5 do 0 :-696
# cond result False
# is cond true False
# odliczanie 5 do 0 :-697
# cond result False
# is cond true False
# odliczanie 5 do 0 :-698
# cond result False
# is cond true False
# odliczanie 5 do 0 :-699
# cond result False
# is cond true False
# odliczanie 5 do 0 :-700
# cond result False
# is cond true False
# odliczanie 5 do 0 :-701
# cond result False
# is cond true False
# odliczanie 5 do 0 :-702
# cond result False
# is cond true False
# odliczanie 5 do 0 :-703
# cond result False
# is cond true False
# odliczanie 5 do 0 :-704
# cond result False
# is cond true False
# odliczanie 5 do 0 :-705
# cond result False
# is cond true False
# odliczanie 5 do 0 :-706
# cond result False
# is cond true False
# odliczanie 5 do 0 :-707
# cond result False
# is cond true False
# odliczanie 5 do 0 :-708
# cond result False
# is cond true False
# odliczanie 5 do 0 :-709
# cond result False
# is cond true False
# odliczanie 5 do 0 :-710
# cond result False
# is cond true False
# odliczanie 5 do 0 :-711
# cond result False
# is cond true False
# odliczanie 5 do 0 :-712
# cond result False
# is cond true False
# odliczanie 5 do 0 :-713
# cond result False
# is cond true False
# odliczanie 5 do 0 :-714
# cond result False
# is cond true False
# odliczanie 5 do 0 :-715
# cond result False
# is cond true False
# odliczanie 5 do 0 :-716
# cond result False
# is cond true False
# odliczanie 5 do 0 :-717
# cond result False
# is cond true False
# odliczanie 5 do 0 :-718
# cond result False
# is cond true False
# odliczanie 5 do 0 :-719
# cond result False
# is cond true False
# odliczanie 5 do 0 :-720
# cond result False
# is cond true False
# odliczanie 5 do 0 :-721
# cond result False
# is cond true False
# odliczanie 5 do 0 :-722
# cond result False
# is cond true False
# odliczanie 5 do 0 :-723
# cond result False
# is cond true False
# odliczanie 5 do 0 :-724
# cond result False
# is cond true False
# odliczanie 5 do 0 :-725
# cond result False
# is cond true False
# odliczanie 5 do 0 :-726
# cond result False
# is cond true False
# odliczanie 5 do 0 :-727
# cond result False
# is cond true False
# odliczanie 5 do 0 :-728
# cond result False
# is cond true False
# odliczanie 5 do 0 :-729
# cond result False
# is cond true False
# odliczanie 5 do 0 :-730
# cond result False
# is cond true False
# odliczanie 5 do 0 :-731
# cond result False
# is cond true False
# odliczanie 5 do 0 :-732
# cond result False
# is cond true False
# odliczanie 5 do 0 :-733
# cond result False
# is cond true False
# odliczanie 5 do 0 :-734
# cond result False
# is cond true False
# odliczanie 5 do 0 :-735
# cond result False
# is cond true False
# odliczanie 5 do 0 :-736
# cond result False
# is cond true False
# odliczanie 5 do 0 :-737
# cond result False
# is cond true False
# odliczanie 5 do 0 :-738
# cond result False
# is cond true False
# odliczanie 5 do 0 :-739
# cond result False
# is cond true False
# odliczanie 5 do 0 :-740
# cond result False
# is cond true False
# odliczanie 5 do 0 :-741
# cond result False
# is cond true False
# odliczanie 5 do 0 :-742
# cond result False
# is cond true False
# odliczanie 5 do 0 :-743
# cond result False
# is cond true False
# odliczanie 5 do 0 :-744
# cond result False
# is cond true False
# odliczanie 5 do 0 :-745
# cond result False
# is cond true False
# odliczanie 5 do 0 :-746
# cond result False
# is cond true False
# odliczanie 5 do 0 :-747
# cond result False
# is cond true False
# odliczanie 5 do 0 :-748
# cond result False
# is cond true False
# odliczanie 5 do 0 :-749
# cond result False
# is cond true False
# odliczanie 5 do 0 :-750
# cond result False
# is cond true False
# odliczanie 5 do 0 :-751
# cond result False
# is cond true False
# odliczanie 5 do 0 :-752
# cond result False
# is cond true False
# odliczanie 5 do 0 :-753
# cond result False
# is cond true False
# odliczanie 5 do 0 :-754
# cond result False
# is cond true False
# odliczanie 5 do 0 :-755
# cond result False
# is cond true False
# odliczanie 5 do 0 :-756
# cond result False
# is cond true False
# odliczanie 5 do 0 :-757
# cond result False
# is cond true False
# odliczanie 5 do 0 :-758
# cond result False
# is cond true False
# odliczanie 5 do 0 :-759
# cond result False
# is cond true False
# odliczanie 5 do 0 :-760
# cond result False
# is cond true False
# odliczanie 5 do 0 :-761
# cond result False
# is cond true False
# odliczanie 5 do 0 :-762
# cond result False
# is cond true False
# odliczanie 5 do 0 :-763
# cond result False
# is cond true False
# odliczanie 5 do 0 :-764
# cond result False
# is cond true False
# odliczanie 5 do 0 :-765
# cond result False
# is cond true False
# odliczanie 5 do 0 :-766
# cond result False
# is cond true False
# odliczanie 5 do 0 :-767
# cond result False
# is cond true False
# odliczanie 5 do 0 :-768
# cond result False
# is cond true False
# odliczanie 5 do 0 :-769
# cond result False
# is cond true False
# odliczanie 5 do 0 :-770
# cond result False
# is cond true False
# odliczanie 5 do 0 :-771
# cond result False
# is cond true False
# odliczanie 5 do 0 :-772
# cond result False
# is cond true False
# odliczanie 5 do 0 :-773
# cond result False
# is cond true False
# odliczanie 5 do 0 :-774
# cond result False
# is cond true False
# odliczanie 5 do 0 :-775
# cond result False
# is cond true False
# odliczanie 5 do 0 :-776
# cond result False
# is cond true False
# odliczanie 5 do 0 :-777
# cond result False
# is cond true False
# odliczanie 5 do 0 :-778
# cond result False
# is cond true False
# odliczanie 5 do 0 :-779
# cond result False
# is cond true False
# odliczanie 5 do 0 :-780
# cond result False
# ...
# odliczanie 5 do 0 :-3313
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3314
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3315
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3316
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3317
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3318
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3319
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3320
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3321
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3322
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3323
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3324
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3325
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3326
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3327
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3328
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3329
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3330
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3331
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3332
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3333
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3334
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3335
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3336
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3337
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3338
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3339
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3340
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3341
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3342
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3343
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3344
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3345
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3346
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3347
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3348
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3349
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3350
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3351
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3352
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3353
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3354
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3355
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3356
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3357
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3358
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3359
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3360
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3361
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3362
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3363
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3364
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3365
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3366
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3367
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3368
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3369
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3370
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3371
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3372
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3373
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3374
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3375
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3376
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3377
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3378
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3379
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3380
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3381
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3382
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3383
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3384
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3385
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3386
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3387
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3388
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3389
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3390
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3391
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3392
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3393
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3394
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3395
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3396
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3397
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3398
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3399
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3400
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3401
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3402
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3403
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3404
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3405
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3406
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3407
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3408
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3409
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3410
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3411
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3412
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3413
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3414
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3415
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3416
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3417
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3418
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3419
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3420
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3421
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3422
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3423
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3424
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3425
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3426
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3427
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3428
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3429
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3430
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3431
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3432
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3433
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3434
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3435
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3436
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3437
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3438
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3439
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3440
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3441
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3442
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3443
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3444
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3445
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3446
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3447
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3448
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3449
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3450
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3451
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3452
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3453
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3454
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3455
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3456
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3457
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3458
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3459
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3460
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3461
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3462
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3463
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3464
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3465
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3466
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3467
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3468
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3469
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3470
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3471
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3472
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3473
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3474
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3475
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3476
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3477
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3478
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3479
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3480
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3481
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3482
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3483
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3484
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3485
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3486
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3487
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3488
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3489
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3490
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3491
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3492
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3493
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3494
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3495
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3496
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3497
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3498
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3499
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3500
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3501
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3502
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3503
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3504
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3505
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3506
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3507
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3508
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3509
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3510
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3511
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3512
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3513
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3514
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3515
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3516
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3517
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3518
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3519
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3520
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3521
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3522
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3523
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3524
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3525
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3526
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3527
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3528
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3529
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3530
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3531
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3532
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3533
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3534
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3535
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3536
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3537
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3538
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3539
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3540
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3541
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3542
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3543
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3544
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3545
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3546
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3547
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3548
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3549
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3550
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3551
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3552
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3553
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3554
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3555
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3556
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3557
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3558
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3559
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3560
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3561
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3562
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3563
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3564
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3565
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3566
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3567
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3568
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3569
# cond result False
# is cond true False
# odliczanie 5 do 0 :-3570
# cond result False
# is cond true False
